# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,2*np.pi,100)
y = np.sin(x)
z = np.cos(x)
plt.plot(x, y,'--r')
plt.plot(x, z,'-k')
plt.legend(["NN", "Multiplicity cut"])
