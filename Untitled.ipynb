# %%
# %%time
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from Functions.Preprocess import events_to_df_vert2, event_to_df_vert1
data_path1 = "Data/macro_test/bb1.RaveGetVertsByJetv2.txt"
data_path2 = "Data/macro_test/bb1.RaveGetVertsByJetv2.txt"

PT_cut = (140, 160)
max_ev = 1000000
n_constits = 50
sort = False
trunc = False

B_jet_path = data_path
B_jet = events_to_df_vert2(B_jet_path, label=0, max_ev=max_ev, n_constits=n_constits, sort=sort, trunc=trunc, PT_cut=PT_cut)
# Out:
# Wall time: 667 ms

# %%
B_jet.head(50)
# Out:
#     Event  Jet        MET   jet_PT   jet_Eta   jet_Phi                n_vert  \
# 0       8    1   27.19790  152.460  0.636567  2.553070            [1.0, 3.0]
# 1      12    2    7.22680  155.605 -1.412460 -0.251404       [1.0, 4.0, 6.0]
# 2      19    2   20.35310  144.499  1.457900  2.689250                 [4.0]
# 3      20    1   18.83930  149.365  0.358754 -0.023653                 [4.0]
# 4      24    1   17.87890  155.153 -0.897669 -1.820590                 [3.0]
# 5      24    2   17.87890  144.560  0.213192  0.981802                 [2.0]
# 6      25    2    6.17251  156.258  1.170030 -0.698063                 [2.0]
# 7      28    2   26.53140  152.601 -2.169700 -1.661940                 [2.0]
# 8      34    2   13.07130  149.309  0.058938  2.386080                 [2.0]
# 9      38    2   20.34180  140.241  1.283950 -0.902037            [1.0, 5.0]
# 10     40    2   23.07310  159.231  1.861760  1.843570                 [3.0]
# ...

# %%
B_jet["mult"] = B_jet.n_vert.map(lambda x: len(x))
B_jet.mult.hist()
plt.
gcf().set_size_inches(10, 10)
