# %%
# %%time
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from Functions.Preprocess import events_to_df_vert2
data_path = "Data/macro_test/bb1.RaveGetVertsByJetv2.txt"

PT_cut = (140, 160)
max_ev = 1000000
n_constits = 50
sort = False
trunc = False

B_jet_path = data_path
B1_jet = events_to_df_vert2(B_jet_path, label=0, max_ev=max_ev, n_constits=n_constits, sort=sort, trunc=trunc, PT_cut=PT_cut)
# Out:
# Wall time: 693 ms

# %%
# %%time
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from Functions.Preprocess import events_to_df_vert1
data_path = "Data/macro_test/bb1.RaveGetVerts.txt"

PT_cut = (140, 160)
max_ev = 1000000
n_constits = 50
sort = False
trunc = False

B_jet_path = data_path
B2_jet = events_to_df_vert1(B_jet_path, label=0, max_ev=max_ev, n_constits=n_constits, sort=sort, trunc=trunc, PT_cut=PT_cut)
# Out:
# Wall time: 1.08 s

# %%
B2_jet.head()
# Out:
#    Event  Jet       MET   jet_PT   jet_Eta   jet_Phi           n_vert  \
# 0      1    1  68.46680  153.974  0.813769  0.462871  [1.0, 2.0, 4.0]
# 1      2    1  15.90340  152.063 -1.529420  0.692719       [1.0, 2.0]
# 2      5    2   5.44335  152.909  0.732531  2.773680  [1.0, 2.0, 3.0]
# 3      6    1  37.38050  147.975  1.324040  1.525620       [1.0, 2.0]
# 4      8    1  27.19790  152.460  0.636567  2.553070       [1.0, 3.0]
#
#                         vert_disp         vert_mult  \
# 0  [0.0182875, 0.50683, 0.295038]  [13.0, 1.0, 1.0]
# 1          [0.00903273, 0.231678]        [7.0, 1.0]
# 2  [0.0188993, 0.174281, 2.44415]   [8.0, 2.0, 2.0]
# 3           [0.0151171, 0.134639]        [9.0, 2.0]
# 4            [0.0306256, 41.2873]        [4.0, 3.0]
#
#                        vert_PT  label
# 0  [14.5143, 11.0239, 18.7647]      0
# 1            [1.3624, 14.5134]      0
# 2  [32.5085, 31.8283, 1.08082]      0
# 3           [20.2647, 4.84447]      0
# ...

# %%
B1_jet.head()
# Out:
#    Event  Jet      MET   jet_PT   jet_Eta   jet_Phi           n_vert  \
# 0      8    1  27.1979  152.460  0.636567  2.553070       [1.0, 3.0]
# 1     12    2   7.2268  155.605 -1.412460 -0.251404  [1.0, 4.0, 6.0]
# 2     19    2  20.3531  144.499  1.457900  2.689250            [4.0]
# 3     20    1  18.8393  149.365  0.358754 -0.023653            [4.0]
# 4     24    1  17.8789  155.153 -0.897669 -1.820590            [3.0]
#
#                         vert_D0         vert_mult  \
# 0          [0.0306256, 41.2873]       [24.0, 3.0]
# 1  [0.0800714, 6.99878, 272.38]  [21.0, 2.0, 2.0]
# 2                     [7.19026]             [2.0]
# 3                     [3.49503]             [2.0]
# 4                     [0.32603]             [2.0]
#
#                        vert_PT  label
# 0           [42.2224, 68.5297]      0
# 1  [94.1496, 4.00019, 6.12057]      0
# 2                    [11.3174]      0
# 3                   [0.628905]      0
# 4                    [4.99921]      0

# %%
B_jet["mult"] = B_jet.n_vert.map(lambda x: len(x))
B_jet.mult.hist()
plt.
gcf().set_size_inches(10, 10)
